# %% [markdown]
# **Exercício 3**
#
# 3 a) Para a realização deste exercício, foram criadas as variáveis com os números primos apresentados no enunciado. Feito isto, os corpos finitos foram criados e armazenados em variáveis para que possa ser usados nos exercícios posteriores.

# %%
p1 = 31
p2 = 127
p3 = 8191
p4 = 131071

# %%
corpo1 = GF(p1)
print(f'Corpo 1: {corpo1}')
corpo2 = GF(p2)
print(f'Corpo 2: {corpo2}')
corpo3 = GF(p3)
print(f'Corpo 3: {corpo3}')
corpo4 = GF(p4)
print(f'Corpo 4: {corpo4}')
# Out:
# Corpo 1: Finite Field of size 31
# Corpo 2: Finite Field of size 127
# Corpo 3: Finite Field of size 8191
# Corpo 4: Finite Field of size 131071

# %% [markdown]
# 3 b) Para criar um gráfico da função $x -> x^2$, foi utilizada a função *list_plot* presente no SageMath.

# %%
list_plot([x^2 for x in corpo1])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
list_plot([x^2 for x in corpo2])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
list_plot([x^2 for x in corpo3])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
list_plot([x^2 for x in corpo4])
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 3 c) Para determinar um elemento primitivo de cada um dos corpos criados, foi utilizado a função *primitive_element* do SageMath. Logo após, foi verificada a proposição imposta no enunciado e concluímos que é verdadeira para todos os corpos criados.

# %%
e1 = corpo1.primitive_element()
print(e1)
n = mod(0, p1 - 1)
e1 ^ n == 1
# Out:
# 3
# True

# %%
e2 = corpo2.primitive_element()
print(e2)
n = mod(0, p1 - 1)
e2 ^ n == 1
# Out:
# 3
# True

# %%
e3 = corpo3.primitive_element()
print(e3)
n = mod(0, p1 - 1)
e3 ^ n == 1
# Out:
# 17
# True

# %%
e4 = corpo4.primitive_element()
print(e4)
n = mod(0, p1 - 1)
e4 ^ n == 1
# Out:
# 3
# True
